# %%
lst = [1,2,3,4,5,6]
lst1 = [i **2  for i in lst if i % 2 == 0 ]
lst1
# Out:
# [4, 16, 36]

# %%
sentence="Hello It is Anjali"
s2=sentence.split()
print(s2)
s1 = [ch for ch in s2 if ch[0] in  'aeiouAEIOU']
print(s1)
# Out:
# ['Hello', 'It', 'is', 'Anjali']
# ['It', 'is', 'Anjali']

# %%
lst = [1,2,2,3,4,4,4,5,6,7,7,8]
set = { i for i in lst if i > 5}
set
# Out:
# {6, 7, 8}

# %%
set = {i for i in range(1,51) if i% 3==0 and i % 5==0}
set
# Out:
# {15, 30, 45}

# %%
dict = { i : i ** 3 for i in range(1,6)}
dict
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %%
dict = {'stu1':45,'stu2':67,'stu3':21,'stu4':90}
dict1 = {name:score for name,score in dict.items() if score >=60 }
dict1
# Out:
# {'stu2': 67, 'stu4': 90}

# %%
import re
print(re.search(r"colou?r","color"))
# Out:
# <re.Match object; span=(0, 5), match='color'>

# %%
evenodd=lambda n:"Even" if n%2 == 0 else "odd"
print(evenodd(5))
# Out:
# odd

# %%
is_float = lambda x:"float" if type(x) == float else 'not float'
print(is_float(10))
# Out:
# not float

# %%
sum = lambda a,b,c: a+b+c 
print(sum(3,4,6))
# Out:
# 13
